# %% [markdown]
# Importing Libraries for Data Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# Loading xlsx file and creating dataframe out of it

# %%
df = pd.read_excel('/content/DS - Assignment Part 1 data set.xlsx')

# %%
df
# Out:
#      Transaction date  House Age  Distance from nearest Metro station (km)  \
# 0         2012.916667       32.0                                  84.87882
# 1         2012.916667       19.5                                 306.59470
# 2         2013.583333       13.3                                 561.98450
# 3         2013.500000       13.3                                 561.98450
# 4         2012.833333        5.0                                 390.56840
# ..                ...        ...                                       ...
# 409       2013.000000       13.7                                4082.01500
# 410       2012.666667        5.6                                  90.45606
# 411       2013.250000       18.8                                 390.96960
# 412       2013.000000        8.1                                 104.81010
# 413       2013.500000        6.5                                  90.45606
#
#      Number of convenience stores  latitude  longitude  Number of bedrooms  \
# 0                              10  24.98298  121.54024                   1
# 1                               9  24.98034  121.53951                   2
# 2                               5  24.98746  121.54391                   3
# 3                               5  24.98746  121.54391                   2
# 4                               5  24.97937  121.54245                   1
# ..                            ...       ...        ...                 ...
# 409                             0  24.94155  121.50381                   3
# 410                             9  24.97433  121.54310                   2
# 411                             7  24.97923  121.53986                   1
# 412                             5  24.96674  121.54067                   1
# 413                             9  24.97433  121.54310                   2
#
#      House size (sqft)  House price of unit area
# 0                  575                      37.9
# 1                 1240                      42.2
# 2                 1060                      47.3
# 3                  875                      54.8
# 4                  491                      43.1
# ..                 ...                       ...
# 409                803                      15.4
# 410               1278                      50.0
# 411                503                      40.6
# 412                597                      52.5
# 413               1097                      63.9
#
# [414 rows x 9 columns]

# %% [markdown]
# Checking for null Values

# %%
df.isnull().sum()
# Out:
# Transaction date                            0
# House Age                                   0
# Distance from nearest Metro station (km)    0
# Number of convenience stores                0
# latitude                                    0
# longitude                                   0
# Number of bedrooms                          0
# House size (sqft)                           0
# House price of unit area                    0
# dtype: int64

# %% [markdown]
# Data is clean

# %% [markdown]
# Data is clean, so next we check it for outliers

# %%
df.describe()
# Out:
#        Transaction date   House Age  Distance from nearest Metro station (km)  \
# count        414.000000  414.000000                                414.000000
# mean        2013.148953   17.712560                               1083.885689
# std            0.281995   11.392485                               1262.109595
# min         2012.666667    0.000000                                 23.382840
# 25%         2012.916667    9.025000                                289.324800
# 50%         2013.166667   16.100000                                492.231300
# 75%         2013.416667   28.150000                               1454.279000
# max         2013.583333   43.800000                               6488.021000
#
#        Number of convenience stores    latitude   longitude  \
# count                    414.000000  414.000000  414.000000
# mean                       4.094203   24.969030  121.533361
# std                        2.945562    0.012410    0.015347
# min                        0.000000   24.932070  121.473530
# 25%                        1.000000   24.963000  121.528085
# 50%                        4.000000   24.971100  121.538630
# 75%                        6.000000   24.977455  121.543305
# max                       10.000000   25.014590  121.566270
#
#        Number of bedrooms  House size (sqft)  House price of unit area
# count          414.000000         414.000000                414.000000
# mean             1.987923         931.475845                 37.980193
# std              0.818875         348.910269                 13.606488
# min              1.000000         402.000000                  7.600000
# 25%              1.000000         548.000000                 27.700000
# 50%              2.000000         975.000000                 38.450000
# 75%              3.000000        1234.750000                 46.600000
# max              3.000000        1500.000000                117.500000

# %%
df.columns
# Out:
# Index(['Transaction date', 'House Age',
#        'Distance from nearest Metro station (km)',
#        'Number of convenience stores', 'latitude', 'longitude',
#        'Number of bedrooms', 'House size (sqft)', 'House price of unit area'],
#       dtype='object')

# %%
plt.rcParams['figure.figsize']= (24,6)

plt.subplot(1,6,1)
sb.boxplot(df['House Age'])
plt.subplot(1,6,2)
sb.boxplot(df['Distance from nearest Metro station (km)'])
plt.subplot(1,6,3)
sb.boxplot(df['Number of convenience stores'])
plt.subplot(1,6,4)
sb.boxplot(df['Number of bedrooms'])
plt.subplot(1,6,5)
sb.boxplot(df['House size (sqft)'])
plt.subplot(1,6,6)
sb.boxplot(df['House price of unit area'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Capping outliers

# %%
df['Distance from nearest Metro station (km)'].values[df['Distance from nearest Metro station (km)'].values>4500]=45000

# %%
df=df[~(df['House price of unit area']>75)]

# %%
df.shape
# Out:
# (411, 9)

# %% [markdown]
# Plotting correlation heatmap. It show how two variables are correlated. Positive Nigative or independent

# %%
sns.heatmap(df.corr(), annot=True,cmap='RdYlBu')

# %%
sns.pairplot(df)

# %%
X= df[['House Age',
       'Distance from nearest Metro station (km)',
       'Number of convenience stores',
       'Number of bedrooms', 'House size (sqft)']]
y= df['House price of unit area']

# %%
# !pip install lazypredict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.8/dist-packages (0.2.12)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from lazypredict) (1.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from lazypredict) (4.64.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.8/dist-packages (from lazypredict) (0.90)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from lazypredict) (1.3.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from lazypredict) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.8/dist-packages (from lazypredict) (2.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from lightgbm->lazypredict) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from lightgbm->lazypredict) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->lazypredict) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->lazypredict) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->lazypredict) (3.1.0)

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

from lazypredict.Supervised import LazyRegressor

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
X_train.shape
# Out:
# (287, 5)

# %% [markdown]
# Here I've used Lazy Regressor which trains data on various vanilla regressors and compare them. Main Advantage of Lazy Regressor is we don't have to import all regressor models one by one individually and decreases the chance of missing a model which will fit best on the data. We don't have to create a function and loop the data with each model to fit().

# %%
reg = LazyRegressor(ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
print(models)
# Out:
# 100%|██████████| 42/42 [00:04<00:00,  9.76it/s]
# [12:25:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#                                Adjusted R-Squared  R-Squared   RMSE  \
# Model
# ExtraTreesRegressor                          0.79       0.80   5.61
# XGBRegressor                                 0.76       0.77   6.04
# GradientBoostingRegressor                    0.76       0.77   6.05
# RandomForestRegressor                        0.75       0.76   6.17
# HistGradientBoostingRegressor                0.74       0.75   6.24
# LGBMRegressor                                0.73       0.74   6.43
# BaggingRegressor                             0.71       0.73   6.56
# AdaBoostRegressor                            0.67       0.68   7.04
# KNeighborsRegressor                          0.56       0.58   8.16
# PoissonRegressor                             0.47       0.49   8.93
# OrthogonalMatchingPursuitCV                  0.45       0.47   9.08
# LassoLarsIC                                  0.45       0.47   9.09
# LassoCV                                      0.45       0.47   9.10
# LassoLarsCV                                  0.45       0.47   9.10
# LarsCV                                       0.45       0.47   9.10
# ElasticNetCV                                 0.45       0.47   9.11
# RidgeCV                                      0.45       0.47   9.13
# BayesianRidge                                0.45       0.47   9.14
# SGDRegressor                                 0.44       0.47   9.15
# Ridge                                        0.44       0.47   9.15
# LinearRegression                             0.44       0.47   9.15
# TransformedTargetRegressor                   0.44       0.47   9.15
# Lars                                         0.44       0.47   9.15
# ExtraTreeRegressor                           0.44       0.47   9.16
# Lasso                                        0.44       0.46   9.20
# HuberRegressor                               0.43       0.46   9.23
# SVR                                          0.42       0.44   9.38
# ElasticNet                                   0.40       0.42   9.53
# NuSVR                                        0.38       0.41   9.63
# LinearSVR                                    0.38       0.41   9.65
# GammaRegressor                               0.37       0.40   9.75
# TweedieRegressor                             0.36       0.38   9.83
# OrthogonalMatchingPursuit                    0.33       0.36  10.02
# DecisionTreeRegressor                        0.32       0.34  10.15
# PassiveAggressiveRegressor                   0.27       0.30  10.46
# LassoLars                                   -0.06      -0.02  12.64
# DummyRegressor                              -0.06      -0.02  12.64
# QuantileRegressor                           -0.10      -0.06  12.87
# MLPRegressor                                -0.16      -0.11  13.23
# KernelRidge                                 -8.93      -8.53  38.68
# RANSACRegressor                            -26.60     -25.47  64.48
# GaussianProcessRegressor                   -77.29     -74.11 108.60
#
#                                Time Taken
# Model
# ExtraTreesRegressor                  0.14
# XGBRegressor                         0.05
# GradientBoostingRegressor            0.09
# RandomForestRegressor                0.26
# HistGradientBoostingRegressor        0.56
# LGBMRegressor                        0.03
# BaggingRegressor                     0.03
# AdaBoostRegressor                    0.04
# KNeighborsRegressor                  0.01
# PoissonRegressor                     0.02
# OrthogonalMatchingPursuitCV          0.04
# LassoLarsIC                          0.03
# LassoCV                              0.08
# LassoLarsCV                          0.08
# LarsCV                               0.03
# ElasticNetCV                         0.05
# RidgeCV                              0.01
# BayesianRidge                        0.01
# SGDRegressor                         0.01
# Ridge                                0.01
# LinearRegression                     0.02
# TransformedTargetRegressor           0.01
# Lars                                 0.02
# ExtraTreeRegressor                   0.01
# Lasso                                0.01
# HuberRegressor                       0.02
# SVR                                  0.02
# ElasticNet                           0.01
# NuSVR                                0.02
# LinearSVR                            0.02
# GammaRegressor                       0.01
# TweedieRegressor                     0.01
# OrthogonalMatchingPursuit            0.02
# DecisionTreeRegressor                0.01
# PassiveAggressiveRegressor           0.02
# LassoLars                            0.03
# DummyRegressor                       0.01
# QuantileRegressor                    1.60
# MLPRegressor                         0.63
# KernelRidge                          0.02
# RANSACRegressor                      0.13
# GaussianProcessRegressor             0.04

# %% [markdown]
# From Lazy Regressor's result, I can conclude that ExtraTreesRegressor is the best as it has high R2 value and lowest RMSE.

# %%
from sklearn.ensemble import ExtraTreesRegressor
ETR = ExtraTreesRegressor()
ETR.fit(X_train,y_train)
# Out:
# ExtraTreesRegressor()

# %%
y_pred = ETR.predict(X_test)
y_pred
# Out:
# array([37.551, 38.762, 41.333, 49.104, 36.48 , 48.211, 36.818, 47.001,
#        45.518, 55.677, 43.899, 16.69 , 29.337, 57.118, 42.834, 46.13 ,
#        37.706, 27.202, 43.64 , 49.332, 39.075, 20.855, 54.835, 49.554,
#        23.424, 50.808, 20.104, 33.434, 42.579, 38.705, 47.596, 38.299,
#        38.316, 36.591, 32.472, 37.06 , 32.638, 24.433, 12.819, 27.902,
#        22.421, 18.39 , 27.413, 34.496, 35.63 , 26.136, 56.696, 19.076,
#        16.874, 39.518, 53.007, 15.422, 54.135, 18.941, 38.925, 28.503,
#        16.098, 31.834, 38.701, 70.158, 59.794, 49.436, 47.468, 42.254,
#        40.58 , 36.647, 25.928, 53.95 , 25.9  , 39.625, 37.005, 49.766,
#        46.563, 45.477, 31.784, 46.71 , 49.501, 13.874, 47.384, 15.28 ,
#        42.734, 36.687, 43.191, 22.156, 40.523, 13.879, 31.706, 37.617,
#        39.947, 19.302, 60.279, 40.308, 38.614, 29.512, 27.231, 37.912,
#        26.796, 53.202, 38.536, 41.458, 47.722, 50.099, 39.284, 33.106,
#        21.03 , 39.089, 40.095, 28.6  , 23.826, 46.378, 46.201, 48.105,
#        18.914, 24.49 , 47.859, 35.891, 40.26 , 47.188, 28.015, 43.578,
#        72.685, 38.942, 28.629, 15.804])

# %%
MAE= metrics.mean_absolute_error(y_test, y_pred)
MSE=metrics.mean_squared_error(y_test, y_pred)
RMSE= np.sqrt(MSE)

# %%
RMSE
# Out:
# 5.799514707172465

# %% [markdown]
# I dit it just to cross-verify Lazy Regressor's result

# %% [markdown]
# Now to predict values using custom input

# %%
print("Enter the Details:")
print("\nHouse Age\nDistance from nearest Metro station (km)\nNumber of convenience stores\nNumber of bedrooms\nHouse size (sqft)\n")
new_data = []
for i in range(0,5):
  ele = input()
  new_data.append(ele)
# Out:
# Enter the Details:
#
# House Age
# Distance from nearest Metro station (km)
# Number of convenience stores
# Number of bedrooms
# House size (sqft)
#
# 32
# 85
# 10
# 1
# 580

# %%
find = pd.DataFrame(new_data).T

# %%
print("Price of house per sqft: ",ETR.predict(find))
# Out:
# Price of house per sqft:  [39.092]
